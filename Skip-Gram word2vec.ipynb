# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import random
from collections import Counter

t = 1e-5
c = Counter(int_words)
total = float(np.sum([e for e in c.values()]))

probs = 1 - np.sqrt(t / np.array([c[w]/total for w in int_words]))

train_words = [e for e, p in zip(int_words, probs) if p < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = random.randint(1, window_size)
    
    return words[idx - R if idx - R >= 0 else 0:idx + 1] + words[idx + 1: idx + 1 + R]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6473 0.4063 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5552 0.4074 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3976 0.3737 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.4030 0.3731 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2969 0.3555 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2842 0.3485 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2739 0.3703 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.2547 0.3441 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1364 0.3432 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1121 0.3509 sec/batch
# Nearest to on: erdrich, novalis, transgressive, illiterate, bosnia, cetacean, kaleidoscope, wca,
# Nearest to united: problems, frankish, eustace, ayyubid, loon, amplifying, hale, halfback,
# Nearest to six: endotherms, ethiopia, five, flattering, cdb, upcoming, meiosis, amiga,
# Nearest to more: clean, observation, wide, harbour, frontman, disagreements, corner, cetaceans,
# Nearest to it: discarded, webzine, aeolian, mortgages, kashubian, present, death, nonaggression,
# Nearest to for: flexed, unassigned, alans, citizenry, presenter, akkad, ceylon, simplicius,
# Nearest to can: soliah, tuner, centromere, dilates, yalu, ronstadt, hireling, tahrir,
# Nearest to some: nasrid, blow, trolling, imperceptible, litigation, remains, whistleblower, infractions,
# Nearest to lived: constitutive, mauritian, furnace, fuel, jonathon, zhdanov, ore, south,
# Nearest to shown: herself, guano, bean, secular, core, npcs, hippolyte, eks,
# Nearest to orthodox: securing, emancipation, monotremes, unix, hough, adherence, undermines, seizes,
# Nearest to alternative: plymouth, germain, accrington, sinister, erupted, basilicas, mustache, eir,
# Nearest to san: contemptuous, mpg, proclus, trucks, transition, champions, moose, invincible,
# Nearest to consists: protagonist, nombre, bears, asn, derive, piedmont, backcountry, receptus,
# Nearest to dr: eero, evolutionist, emigre, pedagogical, unhcr, subtleties, gettysburg, blackberry,
# Nearest to channel: bidatsu, parthenon, interglacial, allowing, erlbaum, and, stability, masts,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1797 0.3658 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0977 0.3405 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0502 0.3401 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9167 0.3397 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9107 0.3393 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8704 0.3399 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8687 0.3386 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8322 0.3791 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7772 0.4373 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7577 0.4199 sec/batch
# Nearest to on: erdrich, earlier, novalis, seriously, cetacean, computer, kaleidoscope, ohio,
# Nearest to united: problems, drawing, done, frankish, compassion, invading, costs, crc,
# Nearest to six: five, endotherms, ethiopia, cdb, upcoming, signifying, flattering, amiga,
# Nearest to more: clean, wide, observation, corner, were, harbour, disagreements, social,
# Nearest to it: discarded, present, such, death, manipulate, case, length, done,
# Nearest to for: developed, presenter, citizenry, exact, tend, unassigned, alans, flexed,
# Nearest to can: tuner, relegated, dilates, not, soliah, johnson, ronstadt, sikhism,
# Nearest to some: litigation, remains, follows, blow, imperceptible, whistleblower, added, states,
# Nearest to lived: constitutive, jonathon, furnace, lumberjack, fuel, south, mauritian, worth,
# Nearest to shown: herself, secular, core, guano, volgograd, animations, saudi, npcs,
# Nearest to orthodox: securing, emancipation, monotremes, adherence, unix, hough, urging, invitation,
# Nearest to alternative: plymouth, erupted, germain, basilicas, sinister, eir, accrington, curtailing,
# Nearest to san: contemptuous, trucks, proclus, transition, mpg, champions, leap, wilson,
# Nearest to consists: protagonist, derive, bears, nombre, heard, piedmont, asn, receptus,
# Nearest to dr: emigre, fi, sperm, statistical, pedagogical, unhcr, eero, evolutionist,
# Nearest to channel: and, bidatsu, allowing, masts, stability, retard, parthenon, famine,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7011 0.4488 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6661 0.4087 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6452 0.4224 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6068 0.4152 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5592 0.4144 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5959 0.4105 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5525 0.4153 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5421 0.4101 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5271 0.4360 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5651 0.4500 sec/batch
# Nearest to on: erdrich, earlier, computer, ohio, novalis, bosnia, cetacean, illiterate,
# Nearest to united: problems, invading, authority, costs, frankish, drawing, defend, eustace,
# Nearest to six: five, upcoming, ethiopia, endotherms, cdb, flattering, signifying, undertaken,
# Nearest to more: clean, wide, observation, disagreements, harbour, frontman, corner, chromosomes,
# Nearest to it: discarded, aeolian, ask, mortgages, commons, webzine, manipulate, present,
# Nearest to for: citizenry, exact, filed, inventions, flexed, bc, flows, unassigned,
# Nearest to can: tuner, relegated, heterosexual, dilates, suicidal, lebanese, sikhism, not,
# Nearest to some: litigation, blow, remains, follows, imperceptible, approach, added, obtains,
# Nearest to lived: constitutive, jonathon, furnace, lumberjack, fuel, worth, debate, south,
# Nearest to shown: herself, guano, secular, animations, core, bean, npcs, volgograd,
# Nearest to orthodox: securing, emancipation, adherence, unix, consortium, invitation, monotremes, hough,
# Nearest to alternative: plymouth, erupted, sinister, germain, basilicas, eir, muslims, supports,
# Nearest to san: contemptuous, proclus, trucks, transition, wilson, mpg, champions, moose,
# Nearest to consists: derive, protagonist, nombre, bears, heard, piedmont, visited, backcountry,
# Nearest to dr: emigre, fi, sperm, statistical, purchase, unhcr, pedagogical, dumping,
# Nearest to channel: bidatsu, stability, allowing, and, masts, famine, fundamentals, interglacial,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.5075 0.4142 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.4844 0.4743 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4548 0.4254 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.4263 0.4112 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4748 0.4321 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4180 0.4116 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.4320 0.4362 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4710 0.4646 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.4189 0.4239 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.4040 0.4241 sec/batch
# Nearest to on: erdrich, ohio, bosnia, illiterate, earlier, transgressive, computer, novalis,
# Nearest to united: problems, invading, frankish, authority, costs, drawing, net, eustace,
# Nearest to six: five, eight, one, upcoming, endotherms, ethiopia, cdb, flattering,
# Nearest to more: clean, wide, disagreements, observation, harbour, expel, chromosomes, frontman,
# Nearest to it: discarded, webzine, aeolian, nonaggression, kashubian, manipulate, ask, mortgages,
# Nearest to for: filed, flexed, inventions, unassigned, citizenry, alans, simplicius, ceylon,
# Nearest to can: tuner, sikhism, affine, heterosexual, lebanese, definitions, suicidal, relegated,
# Nearest to some: litigation, remains, imperceptible, trolling, follows, blow, obtains, added,
# Nearest to lived: constitutive, furnace, jonathon, lumberjack, fuel, south, worth, debate,
# Nearest to shown: herself, guano, animations, secular, core, graziani, norm, npcs,
# Nearest to orthodox: emancipation, securing, adherence, consortium, protestant, authorities, monotremes, unix,
# Nearest to alternative: plymouth, erupted, germain, curtailing, befall, basilicas, sinister, muslims,
# Nearest to san: contemptuous, proclus, mpg, wilson, trucks, transition, moose, champions,
# Nearest to consists: derive, nombre, protagonist, bears, heard, piedmont, backcountry, asn,
# Nearest to dr: emigre, fi, pedagogical, unhcr, eero, evolutionist, sperm, criticizes,
# Nearest to channel: bidatsu, stability, interglacial, masts, allowing, retard, and, parthenon,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3864 0.4271 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.3859 0.4337 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.3385 0.4158 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.3538 0.4067 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3536 0.3763 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.3691 0.3751 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.3488 0.2734 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.3028 0.3761 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.2434 0.3751 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.2625 0.3743 sec/batch
# Nearest to on: erdrich, transgressive, bosnia, friar, illiterate, ohio, computer, earlier,
# Nearest to united: problems, invading, authority, ams, frankish, defeats, mekong, party,
# Nearest to six: five, eight, one, upcoming, endotherms, statesman, ethiopia, cdb,
# Nearest to more: observation, clean, disagreements, wide, harbour, expel, chromosomes, frontman,
# Nearest to it: discarded, nonaggression, aeolian, webzine, kashubian, honestly, carols, manipulate,
# Nearest to for: flexed, filed, unassigned, inventions, citizenry, purchased, simplicius, cordon,
# Nearest to can: tuner, affine, definitions, centromere, suicidal, heterosexual, lebanese, yalu,
# Nearest to some: imperceptible, remains, litigation, trolling, obtains, follows, typical, approach,
# Nearest to lived: furnace, jonathon, constitutive, lumberjack, prompts, fuel, citations, worth,
# Nearest to shown: herself, guano, animations, npcs, norm, aspirin, core, bean,
# Nearest to orthodox: emancipation, adherence, protestant, securing, authorities, seizes, consortium, monotremes,
# Nearest to alternative: plymouth, erupted, germain, befall, basilicas, joule, curtailing, hurled,
# Nearest to san: proclus, contemptuous, mpg, wilson, trucks, jennifer, moose, transition,
# Nearest to consists: nombre, protagonist, derive, bears, backcountry, heard, concentrating, asn,
# Nearest to dr: eero, unhcr, evolutionist, pedagogical, emigre, gettysburg, fi, lady,
# Nearest to channel: bidatsu, parthenon, interglacial, stability, oil, retard, masts, mobility,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.2232 0.3787 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.2263 0.3850 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.2108 0.3892 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.2551 0.3722 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.2196 0.3491 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.2214 0.3454 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.1898 0.3455 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.1537 0.3478 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.1804 0.3450 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.1379 0.3451 sec/batch
# Nearest to on: erdrich, transgressive, computer, bosnia, wca, newsworthy, illiterate, earlier,
# Nearest to united: invading, mekong, amur, foreign, carriers, defeats, party, ams,
# Nearest to six: five, eight, ethiopia, endotherms, flattering, one, cdb, lez,
# Nearest to more: observation, disagreements, clean, chromosomes, wide, expel, harbour, frontman,
# Nearest to it: discarded, aeolian, nonaggression, webzine, kashubian, carols, length, francesc,
# Nearest to for: flexed, filed, unassigned, purchased, cordon, inventions, simplicius, citizenry,
# Nearest to can: affine, definitions, centromere, tuner, suicidal, combinations, comparatively, breathing,
# Nearest to some: remains, obtains, imperceptible, trolling, litigation, typical, approach, follows,
# Nearest to lived: jonathon, furnace, constitutive, lumberjack, mauritian, cartagena, citations, worth,
# Nearest to shown: herself, guano, animations, norm, space, npcs, aspirin, silhouettes,
# Nearest to orthodox: protestant, adherence, emancipation, securing, authorities, seizes, monotremes, invitation,
# Nearest to alternative: plymouth, erupted, germain, befall, joule, curtailing, basilicas, supports,
# Nearest to san: proclus, contemptuous, mpg, wilson, jennifer, moose, gary, trucks,
# Nearest to consists: nombre, bears, backcountry, derive, protagonist, heard, piedmont, plains,
# Nearest to dr: gettysburg, pedagogical, eero, evolutionist, unhcr, lady, criticizes, fi,
# Nearest to channel: bidatsu, interglacial, parthenon, theoretical, caves, insensitivity, masts, maoi,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.1709 0.3843 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.1675 0.3598 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.1769 0.3459 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.1283 0.3448 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.1284 0.3445 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.1733 0.3452 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0865 0.3452 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.1101 0.3448 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.1323 0.3448 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.0939 0.3460 sec/batch
# Nearest to on: erdrich, transgressive, newsworthy, computer, illiterate, earlier, friar, ohio,
# Nearest to united: invading, states, mekong, foreign, amur, party, defeats, torii,
# Nearest to six: five, eight, sunderland, flattering, lez, cdb, ethiopia, one,
# Nearest to more: observation, disagreements, clean, expel, chromosomes, wide, gross, curiously,
# Nearest to it: discarded, aeolian, nonaggression, carols, kashubian, webzine, francesc, snapping,
# Nearest to for: flexed, filed, citizenry, purchased, simplicius, unassigned, airliner, orange,
# Nearest to can: affine, centromere, tuner, definitions, breathing, yalu, cheaper, comparatively,
# Nearest to some: trolling, remains, typical, obtains, imperceptible, litigation, approach, negative,
# Nearest to lived: jonathon, furnace, lumberjack, constitutive, mauritian, cartagena, perverted, citations,
# Nearest to shown: herself, guano, animations, norm, space, aspirin, core, graziani,
# Nearest to orthodox: protestant, adherence, emancipation, orthodoxy, church, theology, rituals, chalcedon,
# Nearest to alternative: plymouth, befall, erupted, joule, curtailing, germain, basilicas, cisc,
# Nearest to san: proclus, contemptuous, jennifer, mpg, gary, wilson, moose, champions,
# Nearest to consists: nombre, backcountry, bears, derive, piedmont, plains, item, asn,
# Nearest to dr: pedagogical, lady, fi, evolutionist, criticizes, gettysburg, eero, unhcr,
# Nearest to channel: bidatsu, interglacial, parthenon, maoi, insensitivity, masts, fields, caves,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.0843 0.3489 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0911 0.3465 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.0556 0.3450 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.0786 0.3450 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.1100 0.3456 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.1081 0.3489 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.1186 0.3586 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.1053 0.3604 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.0173 0.3453 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.0603 0.3472 sec/batch
# Nearest to on: erdrich, transgressive, tanganyika, newsworthy, computer, illiterate, ohio, bosnia,
# Nearest to united: states, foreign, mekong, amur, party, invading, military, policies,
# Nearest to six: five, eight, sunderland, lez, flattering, ethiopia, one, two,
# Nearest to more: expel, observation, clean, disagreements, chromosomes, heliocentric, corner, social,
# Nearest to it: discarded, aeolian, francesc, snapping, ekelund, nonaggression, carols, kashubian,
# Nearest to for: filed, purchased, flexed, simplicius, polisario, unassigned, inheriting, citizenry,
# Nearest to can: tuner, centromere, breathing, affine, cheaper, yalu, definitions, suicidal,
# Nearest to some: trolling, imperceptible, remains, typical, obtains, infractions, nasrid, poudre,
# Nearest to lived: furnace, jonathon, lumberjack, constitutive, cartagena, mauritian, lgbt, perverted,
# Nearest to shown: herself, animations, guano, space, norm, silhouettes, aspirin, graziani,
# Nearest to orthodox: protestant, adherence, orthodoxy, emancipation, church, scriptures, theology, rituals,
# Nearest to alternative: plymouth, befall, erupted, joule, supports, basilicas, germain, curtailing,
# Nearest to san: proclus, gary, contemptuous, jennifer, mpg, moose, francisco, wilson,
# Nearest to consists: nombre, backcountry, bears, plains, derive, piedmont, item, protagonist,
# Nearest to dr: pedagogical, lady, fi, criticizes, gettysburg, evolutionist, eero, acta,
# Nearest to channel: interglacial, bidatsu, theoretical, insensitivity, maoi, niacin, fields, parthenon,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.0784 0.3494 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.0260 0.3458 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0753 0.3456 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0911 0.3463 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.0846 0.3705 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.0033 0.4495 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.0353 0.4554 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.0426 0.4478 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.9336 0.4443 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.0115 0.4414 sec/batch
# Nearest to on: transgressive, erdrich, friar, tanganyika, debuted, ohio, illiterate, earlier,
# Nearest to united: states, mekong, foreign, amur, devaluation, problems, party, torii,
# Nearest to six: five, eight, sunderland, lez, cdb, two, one, runways,
# Nearest to more: expel, clean, observation, disagreements, heliocentric, gross, chromosomes, rhino,
# Nearest to it: aeolian, discarded, ekelund, nonaggression, francesc, soi, snapping, igneous,
# Nearest to for: filed, purchased, polisario, flexed, transputer, simplicius, patents, inv,
# Nearest to can: centromere, tuner, yalu, cheaper, affine, breathing, comparatively, mirrored,
# Nearest to some: remains, typical, trolling, imperceptible, poudre, nasrid, infractions, andes,
# Nearest to lived: furnace, jonathon, lumberjack, mauritian, cartagena, lgbt, remained, cowboy,
# Nearest to shown: herself, animations, guano, silhouettes, graziani, space, norm, aspirin,
# Nearest to orthodox: protestant, adherence, orthodoxy, emancipation, scriptures, theology, coptic, rituals,
# Nearest to alternative: plymouth, befall, joule, supports, germain, bled, cisc, quilt,
# Nearest to san: proclus, gary, francisco, jennifer, contemptuous, mpg, miami, wilson,
# Nearest to consists: nombre, backcountry, bears, piedmont, plains, derive, andaman, receptus,
# Nearest to dr: pedagogical, lady, fi, eero, criticizes, evolutionist, acta, gettysburg,
# Nearest to channel: maoi, insensitivity, interglacial, niacin, bidatsu, gas, eudes, sampling,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.0022 0.4466 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.0028 0.4400 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.0662 0.2027 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9647 0.4393 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.9394 0.3756 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.9280 0.3482 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.9163 0.3428 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.9337 0.3417 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.9338 0.3439 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.8874 0.3433 sec/batch
# Nearest to on: transgressive, erdrich, debuted, tanganyika, friar, adelphi, wca, slowness,
# Nearest to united: states, mekong, nations, devaluation, foreign, amur, expenditure, bombing,
# Nearest to six: five, sunderland, eight, lez, cdb, two, runways, one,
# Nearest to more: expel, clean, observation, disagreements, corner, rhino, heliocentric, luxurious,
# Nearest to it: aeolian, discarded, soi, ekelund, francesc, igneous, nonaggression, carols,
# Nearest to for: filed, purchased, polisario, transputer, patents, unassigned, inv, unwind,
# Nearest to can: centromere, tuner, yalu, breathing, affine, cheaper, unmatched, definitions,
# Nearest to some: remains, trolling, typical, andes, unchanging, poudre, imperceptible, nasrid,
# Nearest to lived: furnace, jonathon, lumberjack, mauritian, cartagena, lgbt, remained, archiepiscopal,
# Nearest to shown: herself, animations, guano, graziani, silhouettes, locative, npcs, aspirin,
# Nearest to orthodox: protestant, orthodoxy, adherence, scriptures, emancipation, coptic, churches, church,
# Nearest to alternative: plymouth, supports, befall, joule, cisc, bled, germain, quilt,
# Nearest to san: proclus, francisco, gary, jennifer, miami, mpg, contemptuous, moose,
# Nearest to consists: nombre, backcountry, bears, piedmont, derive, andaman, plains, toned,
# Nearest to dr: pedagogical, lady, fi, criticizes, evolutionist, unhcr, eero, gettysburg,
# Nearest to channel: niacin, maoi, insensitivity, airforce, bidatsu, ostrava, interglacial, sampling,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.9233 0.3451 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.9331 0.3422 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.9215 0.3420 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.8371 0.3424 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.8913 0.3427 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.8711 0.3410 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.8629 0.3413 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8706 0.3417 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.8956 0.3421 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.8837 0.3418 sec/batch
# Nearest to on: transgressive, erdrich, constancy, newsworthy, debuted, adelphi, battledress, slowness,
# Nearest to united: states, expenditure, devaluation, fukuoka, mekong, amur, bombing, nations,
# Nearest to six: five, sunderland, eight, cdb, endotherms, amiga, two, salvius,
# Nearest to more: expel, disagreements, observation, corner, rhino, social, clean, heliocentric,
# Nearest to it: aeolian, discarded, ekelund, soi, igneous, nonaggression, francesc, webzine,
# Nearest to for: filed, transputer, patents, polisario, purchased, flexed, inv, unwind,
# Nearest to can: centromere, tuner, yalu, breathing, affine, mirrored, comparatively, be,
# Nearest to some: remains, typical, trolling, andes, poudre, unchanging, posh, imperceptible,
# Nearest to lived: furnace, jonathon, lumberjack, mauritian, lgbt, constitutive, cartagena, ungrateful,
# Nearest to shown: herself, animations, guano, graziani, silhouettes, locative, space, aspirin,
# Nearest to orthodox: adherence, protestant, orthodoxy, scriptures, coptic, chalcedon, emancipation, churches,
# Nearest to alternative: plymouth, supports, befall, joule, germain, bled, cisc, kornfeld,
# Nearest to san: francisco, proclus, gary, jennifer, miami, mpg, sooty, trucks,
# Nearest to consists: nombre, piedmont, backcountry, bears, derive, andaman, plains, toned,
# Nearest to dr: pedagogical, fi, criticizes, lady, acta, moo, eero, evolutionist,
# Nearest to channel: niacin, insensitivity, maoi, airforce, caves, bidatsu, ostrava, interglacial,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.8619 0.3451 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.9276 0.3423 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.8706 0.3420 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.8327 0.3432 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8755 0.3425 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.9085 0.3419 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8990 0.3420 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.8238 0.3430 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.8486 0.3429 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8641 0.3412 sec/batch
# Nearest to on: transgressive, erdrich, adelphi, debuted, constancy, battledress, newsworthy, illiterate,
# Nearest to united: states, nations, fukuoka, expenditure, devaluation, torii, micronesia, mekong,
# Nearest to six: five, sunderland, eight, two, three, cdb, one, endotherms,
# Nearest to more: expel, disagreements, social, humour, unchecked, rhino, observation, pid,
# Nearest to it: aeolian, discarded, ekelund, soi, francesc, igneous, playable, nonaggression,
# Nearest to for: filed, patents, transputer, polisario, inv, inheriting, consonance, flexed,
# Nearest to can: centromere, yalu, tuner, breathing, be, hfr, affine, paperwork,
# Nearest to some: typical, trolling, remains, unchanging, poudre, priestly, posh, fezzan,
# Nearest to lived: furnace, jonathon, mauritian, lumberjack, ungrateful, cartagena, lgbt, maquis,
# Nearest to shown: herself, animations, graziani, guano, locative, esp, silhouettes, aspirin,
# Nearest to orthodox: protestant, orthodoxy, adherence, coptic, scriptures, chalcedon, church, churches,
# Nearest to alternative: plymouth, supports, befall, joule, kornfeld, germain, bled, cisc,
# Nearest to san: francisco, proclus, jennifer, gary, miami, sooty, mpg, contemptuous,
# Nearest to consists: nombre, piedmont, backcountry, derive, bears, andaman, portions, plains,
# Nearest to dr: pedagogical, fi, acta, criticizes, lady, moo, sperm, scarface,
# Nearest to channel: niacin, insensitivity, maoi, airforce, freebsd, ostrava, aida, nanotechnology,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8973 0.3448 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8749 0.3412 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8863 0.3434 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8918 0.3417 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.8305 0.3414 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.8481 0.3404 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.8659 0.3424 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.8230 0.3421 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8947 0.3422 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.8867 0.4494 sec/batch
# Nearest to on: transgressive, erdrich, battledress, illiterate, friar, adelphi, debuted, constancy,
# Nearest to united: states, nations, fukuoka, amur, bombing, micronesia, managers, onetime,
# Nearest to six: five, sunderland, eight, three, hines, two, birla, cdb,
# Nearest to more: expel, disagreements, social, humour, rhino, gross, heliocentric, corner,
# Nearest to it: aeolian, discarded, ekelund, soi, francesc, mortgages, igneous, nonaggression,
# Nearest to for: filed, polisario, patents, transputer, consonance, inv, unwind, mss,
# Nearest to can: centromere, yalu, hfr, tuner, cic, breathing, happens, mirrored,
# Nearest to some: unchanging, trolling, typical, remains, poudre, priestly, constituted, fezzan,
# Nearest to lived: furnace, jonathon, mauritian, cartagena, lumberjack, whorehouse, ungrateful, sizeable,
# Nearest to shown: herself, graziani, animations, locative, guano, esp, silhouettes, memoization,
# Nearest to orthodox: adherence, orthodoxy, coptic, protestant, chalcedon, emancipation, churches, scriptures,
# Nearest to alternative: plymouth, supports, befall, germain, bled, kornfeld, quilt, joule,
# Nearest to san: francisco, proclus, jennifer, mpg, gary, miami, sooty, contemptuous,
# Nearest to consists: piedmont, nombre, backcountry, derive, andaman, portions, bears, deteriorates,
# Nearest to dr: pedagogical, acta, criticizes, fi, moo, sperm, lady, scarface,
# Nearest to channel: niacin, freebsd, insensitivity, airforce, maoi, nanotechnology, ostrava, keynote,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.9175 0.4414 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.8338 0.4377 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.8200 0.4382 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.8281 0.4338 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.7540 0.4347 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.8443 0.4340 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.8476 0.4358 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.8162 0.4329 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8613 0.0824 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.8079 0.4336 sec/batch
# Nearest to on: transgressive, erdrich, battledress, adelphi, debuted, constancy, mesons, wca,
# Nearest to united: states, nations, devaluation, fukuoka, micronesia, managers, amur, bombing,
# Nearest to six: five, sunderland, eight, two, three, amiga, endotherms, ethiopia,
# Nearest to more: humour, expel, social, disagreements, rhino, percussive, heliocentric, gross,
# Nearest to it: aeolian, discarded, ekelund, francesc, soi, mortgages, gunns, nonaggression,
# Nearest to for: filed, patents, polisario, inv, transputer, consonance, codifications, unwind,
# Nearest to can: centromere, yalu, tuner, hfr, lebanese, comparatively, happens, unmatched,
# Nearest to some: typical, unchanging, remains, poudre, trolling, priestly, constituted, nasrid,
# Nearest to lived: furnace, jonathon, mauritian, whorehouse, sizeable, cartagena, ungrateful, bertold,
# Nearest to shown: herself, animations, graziani, locative, esp, guano, memoization, silhouettes,
# Nearest to orthodox: adherence, orthodoxy, coptic, protestant, chalcedon, scriptures, emancipation, churches,
# Nearest to alternative: supports, plymouth, kornfeld, befall, germain, bled, joule, transmitter,
# Nearest to san: francisco, proclus, miami, jennifer, sooty, mpg, gary, trucks,
# Nearest to consists: piedmont, nombre, backcountry, derive, andaman, portions, bears, deteriorates,
# Nearest to dr: pedagogical, acta, criticizes, fi, lady, sperm, moo, eero,
# Nearest to channel: niacin, keynote, maoi, nanotechnology, freebsd, airforce, ostrava, insensitivity,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7817 0.4394 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7853 0.4360 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.7928 0.4361 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.7578 0.4188 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.7715 0.3571 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.7194 0.3447 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7737 0.3418 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.7616 0.3418 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.8000 0.3436 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.7074 0.3413 sec/batch
# Nearest to on: transgressive, erdrich, battledress, debuted, adelphi, constancy, hommes, mortgages,
# Nearest to united: states, nations, fukuoka, micronesia, amur, devaluation, managers, mekong,
# Nearest to six: five, sunderland, three, endotherms, two, eight, ethiopia, chalcedon,
# Nearest to more: expel, social, disagreements, humour, percussive, contributing, gross, lusp,
# Nearest to it: aeolian, discarded, ekelund, francesc, soi, cocktails, gunns, regia,
# Nearest to for: filed, patents, polisario, transputer, inv, codifications, unwind, flexed,
# Nearest to can: centromere, tuner, hfr, yalu, unmatched, lebanese, overdoses, cheaper,
# Nearest to some: typical, unchanging, trolling, poudre, remains, constituted, priestly, fezzan,
# Nearest to lived: furnace, jonathon, mauritian, whorehouse, maquis, sizeable, constitutive, ccar,
# Nearest to shown: herself, animations, graziani, locative, esp, memoization, guano, jain,
# Nearest to orthodox: adherence, orthodoxy, coptic, protestant, chalcedon, scriptures, churches, emancipation,
# Nearest to alternative: supports, germain, kornfeld, plymouth, befall, cardiac, shahada, transmitter,
# Nearest to san: francisco, miami, proclus, jose, jennifer, sooty, pes, fresno,
# Nearest to consists: piedmont, nombre, backcountry, portions, derive, andaman, toned, bears,
# Nearest to dr: pedagogical, acta, sperm, moo, lady, criticizes, fi, paxton,
# Nearest to channel: niacin, keynote, maoi, freebsd, nanotechnology, ostrava, viewers, television,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.6817 0.3436 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.7172 0.3430 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.6874 0.3418 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.7269 0.3423 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7632 0.3416 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.7334 0.3415 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7680 0.3424 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7882 0.3430 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.7395 0.3427 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.7264 0.3441 sec/batch
# Nearest to on: transgressive, battledress, erdrich, constancy, distributions, mesons, hommes, datur,
# Nearest to united: states, nations, fukuoka, micronesia, amur, capability, managers, ugle,
# Nearest to six: five, sunderland, three, eight, chalcedon, baselines, two, endotherms,
# Nearest to more: humour, social, lusp, pid, rhino, disagreements, percussive, expel,
# Nearest to it: aeolian, discarded, ekelund, soi, francesc, gunns, cocktails, mortgages,
# Nearest to for: patents, filed, inv, polisario, transputer, codifications, consonance, flexed,
# Nearest to can: centromere, yalu, overdoses, be, happens, unmatched, tuner, affine,
# Nearest to some: typical, unchanging, constituted, trolling, poudre, fezzan, priestly, remains,
# Nearest to lived: jonathon, furnace, mauritian, mountaineer, whorehouse, maquis, biomechanics, sizeable,
# Nearest to shown: animations, herself, graziani, locative, esp, memoization, jain, aspirin,
# Nearest to orthodox: orthodoxy, adherence, coptic, chalcedon, protestant, churches, scriptures, church,
# Nearest to alternative: supports, kornfeld, germain, plymouth, befall, cardiac, transmitter, shahada,
# Nearest to san: francisco, miami, jose, proclus, pes, sooty, fresno, jennifer,
# Nearest to consists: piedmont, nombre, backcountry, portions, derive, andaman, reformulation, toned,
# Nearest to dr: pedagogical, sperm, moo, acta, fi, lady, criticizes, paxton,
# Nearest to channel: niacin, keynote, nanotechnology, ostrava, maoi, airforce, television, insensitivity,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.7538 0.3454 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7779 0.3438 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.7345 0.3434 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.7326 0.3433 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.7185 0.3414 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.7422 0.3414 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7359 0.3414 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.7549 0.3421 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7711 0.3407 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7739 0.3427 sec/batch
# Nearest to on: transgressive, battledress, erdrich, constancy, datur, distributions, hommes, mortgages,
# Nearest to united: states, nations, micronesia, fukuoka, bombing, amur, kingdom, ugle,
# Nearest to six: five, sunderland, chalcedon, endotherms, three, baselines, biblioteca, cdb,
# Nearest to more: humour, lusp, disagreements, expel, rhino, social, contributing, unchecked,
# Nearest to it: aeolian, francesc, ekelund, discarded, soi, gunns, regia, cocktails,
# Nearest to for: patents, filed, polisario, inv, transputer, codifications, consonance, molyneux,
# Nearest to can: centromere, yalu, tuner, overdoses, happens, hfr, gliese, lebanese,
# Nearest to some: typical, trolling, unchanging, poudre, priestly, constituted, fezzan, remains,
# Nearest to lived: furnace, mauritian, whorehouse, jonathon, maquis, bertold, sizeable, sheol,
# Nearest to shown: animations, herself, graziani, locative, esp, taxi, memoization, jain,
# Nearest to orthodox: orthodoxy, adherence, coptic, chalcedon, protestant, scriptures, churches, church,
# Nearest to alternative: supports, kornfeld, plymouth, befall, germain, transmitter, thermostat, cardiac,
# Nearest to san: francisco, proclus, miami, pes, sooty, jose, nigerians, jennifer,
# Nearest to consists: piedmont, nombre, backcountry, portions, derive, toned, andaman, bicameral,
# Nearest to dr: pedagogical, sperm, acta, moo, fi, paxton, sheath, lady,
# Nearest to channel: niacin, viewers, television, airforce, ostrava, nanotechnology, keynote, insensitivity,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.7351 0.3452 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.7010 0.3420 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.7172 0.3418 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7815 0.3427 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.7331 0.3420 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.7868 0.3421 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.8085 0.3415 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.7193 0.3418 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.6992 0.3409 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.7173 0.3417 sec/batch
# Nearest to on: transgressive, battledress, erdrich, datur, arduous, constancy, hommes, cranston,
# Nearest to united: states, nations, micronesia, kingdom, bombing, ugle, seimas, fukuoka,
# Nearest to six: five, sunderland, baselines, chalcedon, endotherms, amiga, cdb, three,
# Nearest to more: humour, lusp, rhino, percussive, disagreements, expel, heliocentric, bj,
# Nearest to it: aeolian, ekelund, discarded, francesc, gunns, soi, cocktails, regia,
# Nearest to for: patents, filed, inv, polisario, codifications, flexed, grayson, transputer,
# Nearest to can: centromere, tuner, happens, yalu, overdoses, be, subcutaneous, hfr,
# Nearest to some: typical, poudre, unchanging, trolling, constituted, mahindra, fezzan, priestly,
# Nearest to lived: whorehouse, mauritian, bertold, furnace, jonathon, mountaineer, maquis, sizeable,
# Nearest to shown: graziani, herself, animations, locative, esp, jain, memoization, sebastien,
# Nearest to orthodox: adherence, orthodoxy, coptic, chalcedon, protestant, churches, scriptures, emancipation,
# Nearest to alternative: supports, plymouth, germain, kornfeld, befall, shahada, quilt, jah,
# Nearest to san: francisco, miami, jose, pes, proclus, sooty, jennifer, diego,
# Nearest to consists: piedmont, bicameral, nombre, backcountry, portions, andaman, deteriorates, derive,
# Nearest to dr: pedagogical, acta, sperm, moo, paxton, fi, scarface, lady,
# Nearest to channel: niacin, keynote, maoi, nanotechnology, airforce, insensitivity, viewers, ostrava,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6773 0.3462 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.7012 0.3415 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.7410 0.3433 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.7001 0.3422 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7671 0.3415 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.7372 0.3158 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.6899 0.3419 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6751 0.3412 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.6688 0.3425 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.6734 0.3413 sec/batch
# Nearest to on: transgressive, battledress, datur, erdrich, arduous, hommes, constancy, distributions,
# Nearest to united: states, nations, micronesia, kingdom, ugle, bombing, fukuoka, managers,
# Nearest to six: five, sunderland, two, three, baselines, four, microprocessors, eight,
# Nearest to more: humour, lusp, social, rhino, percussive, bj, disagreements, contributing,
# Nearest to it: aeolian, discarded, cocktails, gunns, ekelund, soi, francesc, regia,
# Nearest to for: patents, filed, polisario, inv, spalding, grayson, flexed, codifications,
# Nearest to can: centromere, overdoses, tuner, happens, lebanese, subcutaneous, yalu, proud,
# Nearest to some: typical, poudre, unchanging, constituted, trolling, fezzan, priestly, mahindra,
# Nearest to lived: whorehouse, mauritian, maquis, jonathon, furnace, bertold, sizeable, cartagena,
# Nearest to shown: herself, animations, graziani, locative, jain, memoization, esp, unsympathetic,
# Nearest to orthodox: adherence, orthodoxy, coptic, chalcedon, protestant, churches, scriptures, lutheran,
# Nearest to alternative: supports, kornfeld, shahada, drug, cardiac, darwinian, befall, germain,
# Nearest to san: francisco, miami, jose, pes, proclus, diego, sooty, fresno,
# Nearest to consists: piedmont, bicameral, portions, nombre, backcountry, deteriorates, andaman, derive,
# Nearest to dr: pedagogical, acta, moo, sperm, paxton, fi, ursula, criticizes,
# Nearest to channel: keynote, viewers, niacin, nanotechnology, insensitivity, television, ostrava, airforce,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.6733 0.3463 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.6204 0.3425 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.6905 0.3461 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.6898 0.3418 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.6907 0.3431 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6863 0.3421 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.5977 0.3425 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6095 0.3426 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.5896 0.3410 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6411 0.3418 sec/batch
# Nearest to on: transgressive, battledress, hommes, datur, constancy, arduous, erdrich, debuted,
# Nearest to united: states, nations, kingdom, micronesia, ugle, fukuoka, pares, pigpen,
# Nearest to six: five, sunderland, baselines, three, two, chalcedon, four, endotherms,
# Nearest to more: humour, lusp, social, rhino, percussive, pid, bj, indexes,
# Nearest to it: aeolian, cocktails, gunns, discarded, ekelund, soi, regia, mortgages,
# Nearest to for: patents, filed, inv, polisario, flexed, spalding, transputer, codifications,
# Nearest to can: centromere, lebanese, overdoses, tuner, subcutaneous, yalu, be, happens,
# Nearest to some: typical, constituted, poudre, unchanging, fezzan, trolling, preprocessor, litigation,
# Nearest to lived: mauritian, maquis, whorehouse, jonathon, sizeable, furnace, bertold, constitutive,
# Nearest to shown: animations, herself, graziani, esp, jain, locative, memoization, unsympathetic,
# Nearest to orthodox: adherence, orthodoxy, protestant, coptic, chalcedon, churches, odes, lutheran,
# Nearest to alternative: supports, shahada, drug, kornfeld, cardiac, darwinian, germain, befall,
# Nearest to san: francisco, jose, miami, diego, pes, fresno, sooty, proclus,
# Nearest to consists: piedmont, bicameral, portions, nombre, backcountry, andaman, deteriorates, unorganized,
# Nearest to dr: pedagogical, acta, moo, sperm, paxton, romany, fi, ursula,
# Nearest to channel: viewers, television, keynote, caves, niacin, arabsat, insensitivity, nanotechnology,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6612 0.3456 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.6751 0.3420 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.6441 0.3429 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.6688 0.3426 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.7174 0.3427 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6134 0.3415 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.6605 0.3427 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.6833 0.3437 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6649 0.3424 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6502 0.3436 sec/batch
# Nearest to on: transgressive, battledress, datur, hommes, distributions, erdrich, constancy, adelphi,
# Nearest to united: states, nations, kingdom, micronesia, ugle, fukuoka, torii, newsradio,
# Nearest to six: five, sunderland, three, baselines, cdb, two, four, chalcedon,
# Nearest to more: humour, lusp, rhino, social, percussive, indexes, bj, gross,
# Nearest to it: aeolian, ekelund, gunns, soi, discarded, cocktails, francesc, excesses,
# Nearest to for: patents, filed, inv, polisario, grayson, consonance, codifications, stopwatch,
# Nearest to can: centromere, overdoses, tuner, yalu, subcutaneous, lebanese, be, cic,
# Nearest to some: typical, constituted, poudre, unchanging, priestly, trolling, fezzan, ordaining,
# Nearest to lived: whorehouse, mauritian, maquis, jonathon, bertold, constitutive, masochism, mountaineer,
# Nearest to shown: animations, herself, graziani, esp, jain, locative, unsympathetic, memoization,
# Nearest to orthodox: orthodoxy, adherence, chalcedon, coptic, churches, church, protestant, eastern,
# Nearest to alternative: supports, drug, cardiac, eddies, kornfeld, shahada, plymouth, darwinian,
# Nearest to san: francisco, jose, miami, pes, diego, proclus, sacramento, sooty,
# Nearest to consists: piedmont, bicameral, nombre, portions, backcountry, deteriorates, toned, derive,
# Nearest to dr: moo, pedagogical, paxton, acta, sperm, sheath, ursula, fi,
# Nearest to channel: viewers, keynote, caves, television, niacin, insensitivity, arabsat, nanotechnology,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6791 0.3479 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6546 0.3430 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6581 0.3426 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6695 0.3429 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.6895 0.3411 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.6647 0.3417 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6387 0.3406 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.6596 0.3428 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.6239 0.3425 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.7005 0.3420 sec/batch
# Nearest to on: transgressive, battledress, datur, arduous, hommes, constancy, distributions, mesons,
# Nearest to united: states, nations, kingdom, micronesia, ugle, us, bombing, pigpen,
# Nearest to six: five, sunderland, three, baselines, chalcedon, cdb, four, two,
# Nearest to more: humour, lusp, social, rhino, gross, indexes, percussive, expel,
# Nearest to it: aeolian, ekelund, gunns, cocktails, regia, soi, discarded, mortgages,
# Nearest to for: patents, filed, polisario, inv, codifications, guinean, eui, ipo,
# Nearest to can: centromere, overdoses, happens, tuner, yalu, subcutaneous, lebanese, proud,
# Nearest to some: typical, constituted, poudre, priestly, trolling, unchanging, fezzan, ordaining,
# Nearest to lived: bertold, mauritian, whorehouse, remained, sizeable, cartagena, maquis, constitutive,
# Nearest to shown: animations, herself, graziani, jain, locative, esp, unsympathetic, memoization,
# Nearest to orthodox: orthodoxy, adherence, coptic, chalcedon, churches, church, protestant, odes,
# ...
# Nearest to consists: piedmont, bicameral, unorganized, backcountry, legislative, consisting, appoints, sarkozy,
# Nearest to dr: paxton, shaggy, moo, ursula, sheath, wm, serious, mba,
# Nearest to channel: viewers, aired, waves, nanotechnology, television, caves, keynote, ostrava,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.4944 0.3468 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.5244 0.3432 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.5103 0.3436 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.5016 0.3417 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.4900 0.3416 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5070 0.3420 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.5153 0.3413 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.4907 0.3427 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.5653 0.3427 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.5346 0.3428 sec/batch
# Nearest to on: lecture, battledress, dispelled, feuerbach, sidemen, gabbro, accepting, mistaken,
# Nearest to united: states, kingdom, nations, us, dmu, prior, hutterites, ugle,
# Nearest to six: five, sunderland, baselines, age, biblioteca, microprocessors, endotherms, zeno,
# Nearest to more: lusp, humour, meissen, hydrolyze, abba, social, indexes, bevel,
# Nearest to it: aeolian, regia, excesses, counterexamples, salford, pindus, exner, gunns,
# Nearest to for: thirties, patents, gfdl, ratifying, disposal, bc, kahuna, impersonator,
# Nearest to can: subcutaneous, overdoses, proud, hydrate, widehat, laureates, awe, antioxidant,
# Nearest to some: ordaining, constituted, unchanging, selwyn, nevada, sadler, typical, dunham,
# Nearest to lived: remained, abandon, schoolmaster, bertold, architecturally, lye, thrilling, whorehouse,
# Nearest to shown: shows, animations, has, tweet, aired, television, jain, herself,
# Nearest to orthodox: orthodoxy, eastern, kapor, adherence, patriarch, coptic, churches, chalcedon,
# Nearest to alternative: complementary, silicate, translational, der, administer, thermostat, ksi, eddies,
# Nearest to san: francisco, diego, jose, sacramento, harmful, miami, pes, preserver,
# Nearest to consists: piedmont, bicameral, backcountry, unorganized, warrior, appoints, consisting, legislative,
# Nearest to dr: paxton, shaggy, ursula, moo, sheath, wm, acta, mba,
# Nearest to channel: viewers, aired, nanotechnology, waves, insensitivity, caves, television, keynote,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.5180 0.3459 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.5050 0.3453 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.4885 0.3445 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.4934 0.3460 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.5717 0.3440 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5287 0.3434 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.6341 0.3428 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5508 0.3419 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.5685 0.3417 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.4853 0.3426 sec/batch
# Nearest to on: lecture, battledress, dispelled, gabbro, sidemen, feuerbach, accepting, mistaken,
# Nearest to united: states, kingdom, nations, hutterites, us, prior, dmu, ugle,
# Nearest to six: five, sunderland, age, baselines, biblioteca, microprocessors, endotherms, four,
# Nearest to more: lusp, humour, meissen, hydrolyze, indexes, curiously, abba, bevel,
# Nearest to it: regia, aeolian, counterexamples, excesses, pindus, salford, gunns, exner,
# Nearest to for: thirties, patents, gfdl, ratifying, lodged, mtnl, disposal, bc,
# Nearest to can: subcutaneous, overdoses, proud, widehat, laureates, awe, centromere, hydrate,
# Nearest to some: unchanging, ordaining, constituted, nevada, selwyn, preprocessor, dunham, fezzan,
# Nearest to lived: remained, abandon, schoolmaster, bertold, architecturally, lye, thrilling, whorehouse,
# Nearest to shown: shows, animations, has, jain, tweet, ashmole, vigen, herself,
# Nearest to orthodox: orthodoxy, adherence, kapor, coptic, patriarch, eastern, indoors, emancipation,
# Nearest to alternative: complementary, silicate, der, administer, ksi, eddies, thermostat, shahada,
# Nearest to san: francisco, diego, jose, harmful, sacramento, pes, miami, preserver,
# Nearest to consists: piedmont, bicameral, unorganized, backcountry, appoints, consisting, warrior, ireann,
# Nearest to dr: paxton, ursula, shaggy, moo, mba, acta, wm, maxfield,
# Nearest to channel: viewers, aired, nanotechnology, insensitivity, caves, waves, maoi, operators,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.4499 0.3471 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.5115 0.3435 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4515 0.3428 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5449 0.3433 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.4812 0.3439 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.5041 0.3420 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5598 0.1955 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.4942 0.3422 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.5227 0.3452 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.4954 0.3442 sec/batch
# Nearest to on: lecture, dispelled, battledress, feuerbach, llywelyn, mistaken, gabbro, datur,
# Nearest to united: states, kingdom, nations, hutterites, us, dmu, prior, descriptors,
# Nearest to six: five, sunderland, baselines, microprocessors, age, four, biblioteca, delambre,
# Nearest to more: lusp, humour, meissen, hydrolyze, approach, uncharacteristically, social, than,
# Nearest to it: regia, aeolian, exner, salford, pindus, excesses, gunns, stables,
# Nearest to for: thirties, patents, gfdl, disposal, kahuna, bc, ratifying, pvt,
# Nearest to can: subcutaneous, proud, overdoses, widehat, laureates, centromere, hydrate, bandy,
# Nearest to some: unchanging, ordaining, constituted, selwyn, diomedea, dunham, sadler, nevada,
# Nearest to lived: remained, abandon, schoolmaster, thrilling, bertold, architecturally, lye, echinoderms,
# Nearest to shown: animations, shows, has, jain, tweet, ashmole, herself, unsympathetic,
# Nearest to orthodox: orthodoxy, kapor, adherence, eastern, indoors, patriarch, coptic, emancipation,
# Nearest to alternative: complementary, isps, administer, silicate, shahada, thermostat, ksi, der,
# Nearest to san: francisco, diego, jose, miami, sacramento, harmful, pes, blowout,
# Nearest to consists: piedmont, bicameral, backcountry, unorganized, consisting, portions, warrior, appoints,
# Nearest to dr: paxton, ursula, moo, shaggy, mba, wm, reconstituted, reestablish,
# Nearest to channel: viewers, aired, nanotechnology, waves, insensitivity, caves, keynote, maoi,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.4716 0.3461 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.4614 0.3421 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.4794 0.3435 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.4666 0.3421 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.5132 0.3428 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.4589 0.3414 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.5537 0.3413 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4000 0.3419 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.4491 0.3432 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.4404 0.3429 sec/batch
# Nearest to on: lecture, battledress, dispelled, mistaken, gabbro, datur, sidemen, llywelyn,
# Nearest to united: states, kingdom, nations, hutterites, us, dmu, prior, descriptors,
# Nearest to six: five, baselines, sunderland, age, microprocessors, cen, endotherms, biblioteca,
# Nearest to more: lusp, humour, meissen, hydrolyze, approach, bevel, curiously, uncharacteristically,
# Nearest to it: regia, aeolian, gunns, excesses, pindus, counterexamples, salford, exner,
# Nearest to for: thirties, patents, gfdl, disposal, bc, mtnl, kahuna, ratifying,
# Nearest to can: subcutaneous, proud, overdoses, widehat, laureates, centromere, awe, hydrate,
# Nearest to some: ordaining, constituted, unchanging, preprocessor, selwyn, dunham, nevada, diomedea,
# Nearest to lived: abandon, remained, schoolmaster, lye, architecturally, bertold, thrilling, bushmen,
# Nearest to shown: shows, animations, has, jain, tweet, pointer, ashmole, unsympathetic,
# Nearest to orthodox: orthodoxy, kapor, adherence, eastern, indoors, patriarch, coptic, churches,
# Nearest to alternative: complementary, silicate, administer, isps, der, ksi, shahada, ueshiba,
# Nearest to san: francisco, diego, jose, sacramento, harmful, miami, pes, blowout,
# Nearest to consists: piedmont, bicameral, unorganized, backcountry, consisting, portions, legislative, sarkozy,
# Nearest to dr: paxton, ursula, moo, wm, reconstituted, shaggy, acta, reestablish,
# Nearest to channel: viewers, aired, nanotechnology, waves, television, insensitivity, itv, tv,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.3976 0.3460 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.5074 0.3429 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.5095 0.3431 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.4765 0.3428 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.4639 0.3418 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.5787 0.3427 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.5120 0.3441 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.4666 0.3414 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.4899 0.3421 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.5116 0.3418 sec/batch
# Nearest to on: lecture, dispelled, battledress, mistaken, sidemen, feuerbach, gabbro, datur,
# Nearest to united: states, kingdom, nations, hutterites, dmu, us, ugle, prior,
# Nearest to six: sunderland, five, baselines, age, microprocessors, biblioteca, cen, cdb,
# Nearest to more: lusp, humour, approach, meissen, hydrolyze, repudiate, bevel, uncharacteristically,
# Nearest to it: aeolian, excesses, regia, counterexamples, gunns, salford, pindus, exner,
# Nearest to for: thirties, patents, gfdl, mtnl, kahuna, ratifying, disposal, bc,
# Nearest to can: proud, overdoses, widehat, subcutaneous, awe, laureates, bandy, scant,
# Nearest to some: ordaining, selwyn, constituted, unchanging, sadler, dunham, preprocessor, typical,
# Nearest to lived: abandon, remained, schoolmaster, thrilling, lye, whorehouse, architecturally, bushmen,
# Nearest to shown: animations, shows, has, television, aired, tweet, jain, pbs,
# Nearest to orthodox: orthodoxy, eastern, church, kapor, churches, adherence, coptic, patriarch,
# Nearest to alternative: complementary, silicate, administer, isps, thermostat, ksi, translational, choice,
# Nearest to san: francisco, jose, diego, sacramento, miami, harmful, pes, preserver,
# Nearest to consists: piedmont, bicameral, unorganized, backcountry, consisting, reformulation, legislative, responsiveness,
# Nearest to dr: paxton, shaggy, ursula, serious, polycystic, wm, moo, scarface,
# Nearest to channel: viewers, aired, nanotechnology, insensitivity, waves, baptisms, itv, surrender,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.5445 0.3476 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.4965 0.3425 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.4700 0.3432 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.4756 0.3435 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.5447 0.3417 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.5175 0.3431 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.4854 0.3429 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.5112 0.3429 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.4583 0.3426 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.4530 0.3415 sec/batch
# Nearest to on: lecture, dispelled, battledress, mistaken, reflecting, gabbro, offical, accepting,
# Nearest to united: states, kingdom, nations, hutterites, us, dmu, ugle, pares,
# Nearest to six: sunderland, five, baselines, age, microprocessors, biblioteca, endotherms, three,
# Nearest to more: lusp, humour, meissen, hydrolyze, repudiate, approach, than, uncharacteristically,
# Nearest to it: aeolian, excesses, gunns, regia, raj, counterexamples, pindus, exner,
# Nearest to for: patents, thirties, gfdl, mtnl, ratifying, disposal, ipo, filed,
# Nearest to can: overdoses, proud, widehat, subcutaneous, awe, laureates, centromere, hydrate,
# Nearest to some: ordaining, unchanging, selwyn, constituted, sadler, preprocessor, dunham, lfar,
# Nearest to lived: remained, abandon, schoolmaster, thrilling, architecturally, bushmen, bertold, lye,
# Nearest to shown: animations, shows, has, television, aired, pbs, jain, tweet,
# Nearest to orthodox: orthodoxy, kapor, adherence, eastern, churches, church, coptic, indoors,
# Nearest to alternative: complementary, administer, thermostat, silicate, translational, exists, ksi, choice,
# Nearest to san: francisco, jose, diego, sacramento, harmful, miami, preserver, blowout,
# Nearest to consists: piedmont, bicameral, consisting, unorganized, backcountry, reformulation, warrior, portions,
# Nearest to dr: paxton, ursula, shaggy, reconstituted, scarface, acta, polycystic, reestablish,
# Nearest to channel: viewers, aired, nanotechnology, insensitivity, connect, operators, isdb, waves,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.5401 0.3460 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.5277 0.3430 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.5868 0.3441 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.5479 0.3444 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.5322 0.3431 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.5012 0.3434 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.4085 0.3425 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.4880 0.3430 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.4134 0.3422 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.5132 0.3415 sec/batch
# Nearest to on: lecture, battledress, dispelled, gabbro, mistaken, rediscovering, llywelyn, sidemen,
# Nearest to united: states, kingdom, nations, hutterites, us, pares, declares, dmu,
# Nearest to six: sunderland, five, baselines, age, seven, leyla, one, wheatley,
# Nearest to more: lusp, meissen, humour, approach, hydrolyze, uncharacteristically, repudiate, than,
# Nearest to it: aeolian, regia, gunns, exner, counterexamples, excesses, headlines, salford,
# Nearest to for: thirties, patents, gfdl, mtnl, ratifying, pvt, kahuna, uses,
# Nearest to can: widehat, overdoses, proud, subcutaneous, laureates, centromere, awe, hydrate,
# Nearest to some: ordaining, unchanging, selwyn, constituted, sadler, preprocessor, dunham, nevada,
# Nearest to lived: remained, abandon, schoolmaster, lye, bertold, architecturally, thrilling, bushmen,
# Nearest to shown: animations, shows, has, aired, jain, tweet, television, pbs,
# Nearest to orthodox: orthodoxy, kapor, adherence, eastern, coptic, indoors, chalcedon, patriarch,
# Nearest to alternative: complementary, silicate, ksi, administer, shahada, thermostat, choice, der,
# Nearest to san: francisco, jose, diego, sacramento, miami, harmful, blowout, preserver,
# Nearest to consists: piedmont, bicameral, consisting, unorganized, legislative, backcountry, warrior, appoints,
# Nearest to dr: paxton, ursula, reconstituted, shaggy, upton, polycystic, scarface, reestablish,
# Nearest to channel: viewers, aired, nanotechnology, insensitivity, connect, surrender, operators, alltel,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.4909 0.3463 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.4802 0.3440 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /Users/renatoc/Applications/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/renatoc/Applications/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
